# %% [markdown]
# <a href="https://colab.research.google.com/github/rauniyarmanish563-bot/Python-Coding-Challenge--2-/blob/main/Program%20to%20%20check%20if%20string%20is%20palindrome.%20%20%20%20%20%20%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function to check palindrome
def is_palindrome(s):
    # Compare string with reverse
    if s == s[::-1]:
        return "Yes"
    else:
        return "No"

# Input
text = input("Enter string: ")

# Output
print(is_palindrome(text))
# Out:
# Enter string: "madam"
# Yes
