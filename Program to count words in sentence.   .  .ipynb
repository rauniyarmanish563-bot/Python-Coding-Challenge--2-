# %% [markdown]
# <a href="https://colab.research.google.com/github/rauniyarmanish563-bot/Python-Coding-Challenge--2-/blob/main/Program%20to%20count%20words%20in%20sentence.%20%20%20.%20%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function to count words
def count_words(s):
    words = s.split()
    return len(words)

# Input
text = input("Enter sentence: ")

# Output
print("Word count:", count_words(text))
# Out:
# Enter sentence: "Python is great"
# Word count: 3
