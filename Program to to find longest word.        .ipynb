# %% [markdown]
# <a href="https://colab.research.google.com/github/rauniyarmanish563-bot/Python-Coding-Challenge--2-/blob/main/Program%20to%20to%20find%20longest%20word.%20%20%20%20%20%20%20%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function to find longest word
def longest_word(s):
    words = s.split()
    longest = words[0]

    for word in words:
        if len(word) > len(longest):
            longest = word

    return longest

# Input
text = input("Enter sentence: ")
# Out:
# Enter sentence: " I Love Programming "
# Longest word: Programming
