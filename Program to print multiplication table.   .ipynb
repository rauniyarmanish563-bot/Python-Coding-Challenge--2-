# %% [markdown]
# <a href="https://colab.research.google.com/github/rauniyarmanish563-bot/Python-Coding-Challenge--2-/blob/main/Program%20to%20print%20multiplication%20table.%20%20%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function to print table
def print_table(n):
    # Loop from 1 to 10
    for i in range(1, 11):
        print(n * i, end=" ")

# Taking input
num = int(input("Enter number: "))

# Calling function
print_table(num)
# Out:
# Enter number: 3
# 3 6 9 12 15 18 21 24 27 30
