# %% [markdown]
# <a href="https://colab.research.google.com/github/rauniyarmanish563-bot/Python-Coding-Challenge--2-/blob/main/Program%20to%20check%20if%20a%20number%20satisfies%20this%20condition.%20%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function to check divisibility
def check_number(num):
    # Check if number is divisible by both 3 and 5
    if num % 3 == 0 and num % 5 == 0:
        return "Yes"
    else:
        return "No"

# Taking input from user
num = int(input("Enter number: "))

# Calling function and printing result
print(check_number(num))
# Out:
# Enter number: 15
# Yes
