# %% [markdown]
# <a href="https://colab.research.google.com/github/rauniyarmanish563-bot/Python-Coding-Challenge--2-/blob/main/Program%20to%20reverse%20a%20number.%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function to reverse number
def reverse_number(num):
    rev = 0

    # Loop until number becomes 0
    while num > 0:
        digit = num % 10        # get last digit
        rev = rev * 10 + digit # build reversed number
        num = num // 10        # remove last digit

    return rev

# Taking input
num = int(input("Enter number: "))

# Calling function
print("Reversed:", reverse_number(num))
# Out:
# Enter number: 1234
# Reversed: 4321
