# %% [markdown]
# <a href="https://colab.research.google.com/github/rauniyarmanish563-bot/Python-Coding-Challenge--2-/blob/main/Program%20to%20classify%20the%20user%20as%20Minor%2C%20Adult%2C%20or%20Senior.%20%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function to classify age group
def classify_age(age):
    # If age is less than 18
    if age < 18:
        return "Minor"

    # If age is between 18 and 59
    elif age < 60:
        return "Adult"

    # If age is 60 or above
    else:
        return "Senior"

# Taking input from user
age = int(input("Enter age: "))

# Calling function and printing result
print("Category:", classify_age(age))
# Out:
# Enter age: 65
# Category: Senior
