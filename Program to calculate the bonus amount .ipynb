# %% [markdown]
# <a href="https://colab.research.google.com/github/rauniyarmanish563-bot/Python-Coding-Challenge--2-/blob/main/Program%20to%20calculate%20the%20bonus%20amount%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculate_bonus(salary):
    bonus = salary * 0.07
    return bonus

# Input
salary = int(input("Enter salary: "))
print("Bonus =", int(calculate_bonus(salary)))
# Out:
# Enter salary: 45000
# Bonus = 3150
