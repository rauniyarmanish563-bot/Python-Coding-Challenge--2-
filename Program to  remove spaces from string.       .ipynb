# %% [markdown]
# <a href="https://colab.research.google.com/github/rauniyarmanish563-bot/Python-Coding-Challenge--2-/blob/main/Program%20to%20%20remove%20spaces%20from%20string.%20%20%20%20%20%20%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function to remove spaces
def remove_spaces(s):
    result = ""

    for ch in s:
        if ch != " ":
            result += ch

    return result

# Input
text = input("Enter string: ")

# Output
print(remove_spaces(text))
# Out:
# Enter string: "hello world"
# "helloworld"
